# %%
import pandas as pd

# %% [markdown]
# ##merge the 12 months of sales months of data

# %%
df = pd.read_csv("/content/Sales_April_2019.csv")
df
# Out:
#       Order ID  ...                        Purchase Address
# 0       176558  ...            917 1st St, Dallas, TX 75001
# 1          NaN  ...                                     NaN
# 2       176559  ...       682 Chestnut St, Boston, MA 02215
# 3       176560  ...    669 Spruce St, Los Angeles, CA 90001
# 4       176560  ...    669 Spruce St, Los Angeles, CA 90001
# ...        ...  ...                                     ...
# 18378   194090  ...   177 Jackson St, Los Angeles, CA 90001
# 18379   194091  ...         311 Forest St, Austin, TX 73301
# 18380   194092  ...  347 Sunset St, San Francisco, CA 94016
# 18381   194093  ...         835 Lake St, Portland, OR 97035
# 18382   194094  ...          354 North St, Boston, MA 02215
#
# [18383 rows x 6 columns]

# %%
df1 = pd.read_csv("/content/Sales_August_2019.csv")
df1.head()
# Out:
#   Order ID  ...                      Purchase Address
# 0   236670  ...      359 Spruce St, Seattle, WA 98101
# 1   236671  ...        492 Ridge St, Dallas, TX 75001
# 2   236672  ...        149 7th St, Portland, OR 97035
# 3   236673  ...     631 2nd St, Los Angeles, CA 90001
# 4   236674  ...  736 14th St, New York City, NY 10001
#
# [5 rows x 6 columns]

# %%
df2 = pd.read_csv("/content/Sales_December_2019.csv")
df2.head()
# Out:
#   Order ID  ...                        Purchase Address
# 0   295665  ...  136 Church St, New York City, NY 10001
# 1   295666  ...     562 2nd St, New York City, NY 10001
# 2   295667  ...    277 Main St, New York City, NY 10001
# 3   295668  ...     410 6th St, San Francisco, CA 94016
# 4   295669  ...           43 Hill St, Atlanta, GA 30301
#
# [5 rows x 6 columns]

# %%
df3 = pd.read_csv("/content/Sales_February_2019.csv")
df3.head()
# Out:
#   Order ID  ...                     Purchase Address
# 0   150502  ...    866 Spruce St, Portland, ME 04101
# 1   150503  ...  18 13th St, San Francisco, CA 94016
# 2   150504  ...   52 6th St, New York City, NY 10001
# 3   150505  ...     129 Cherry St, Atlanta, GA 30301
# 4   150506  ...    548 Lincoln St, Seattle, WA 98101
#
# [5 rows x 6 columns]

# %%
df4 = pd.read_csv("/content/Sales_January_2019.csv")
df4.head()
# Out:
#   Order ID  ...                       Purchase Address
# 0   141234  ...        944 Walnut St, Boston, MA 02215
# 1   141235  ...       185 Maple St, Portland, OR 97035
# 2   141236  ...  538 Adams St, San Francisco, CA 94016
# 3   141237  ...     738 10th St, Los Angeles, CA 90001
# 4   141238  ...          387 10th St, Austin, TX 73301
#
# [5 rows x 6 columns]

# %%
df5 = pd.read_csv("/content/Sales_July_2019.csv")
df5.head()
# Out:
#   Order ID  ...                  Purchase Address
# 0   222910  ...   389 South St, Atlanta, GA 30301
# 1   222911  ...     590 4th St, Seattle, WA 98101
# 2   222912  ...    861 Hill St, Atlanta, GA 30301
# 3   222913  ...   190 Ridge St, Atlanta, GA 30301
# 4   222914  ...  824 Forest St, Seattle, WA 98101
#
# [5 rows x 6 columns]

# %%
df6 = pd.read_csv("/content/Sales_June_2019.csv")
df6.head()
# Out:
#   Order ID  ...                       Purchase Address
# 0   209921  ...      950 Walnut St, Portland, ME 04101
# 1   209922  ...     80 4th St, San Francisco, CA 94016
# 2   209923  ...  402 Jackson St, Los Angeles, CA 90001
# 3   209924  ...         560 10th St, Seattle, WA 98101
# 4   209925  ...    545 2nd St, San Francisco, CA 94016
#
# [5 rows x 6 columns]

# %%
df7 = pd.read_csv("/content/Sales_March_2019.csv")
df7.head()
# Out:
#   Order ID  ...                      Purchase Address
# 0   162009  ...       942 Church St, Austin, TX 73301
# 1   162009  ...       942 Church St, Austin, TX 73301
# 2   162009  ...       942 Church St, Austin, TX 73301
# 3   162010  ...  261 10th St, San Francisco, CA 94016
# 4   162011  ...  764 13th St, San Francisco, CA 94016
#
# [5 rows x 6 columns]

# %%
df8 = pd.read_csv("/content/Sales_May_2019.csv")
df8.head()
# Out:
#   Order ID  ...                         Purchase Address
# 0   194095  ...      669 2nd St, New York City, NY 10001
# 1   194096  ...          844 Walnut St, Dallas, TX 75001
# 2   194097  ...  164 Madison St, New York City, NY 10001
# 3   194098  ...          622 Meadow St, Dallas, TX 75001
# 4   194099  ...          17 Church St, Seattle, WA 98101
#
# [5 rows x 6 columns]

# %%
df9 = pd.read_csv("/content/Sales_November_2019.csv")
df9.head()
# Out:
#   Order ID  ...                      Purchase Address
# 0   278797  ...   46 Park St, New York City, NY 10001
# 1   278798  ...      962 Hickory St, Austin, TX 73301
# 2   278799  ...  464 Cherry St, Los Angeles, CA 90001
# 3   278800  ...        649 10th St, Seattle, WA 98101
# 4   278801  ...         522 Hill St, Boston, MA 02215
#
# [5 rows x 6 columns]

# %%
df10 = pd.read_csv("/content/Sales_October_2019.csv")
df10.head()
# Out:
#   Order ID  ...                           Purchase Address
# 0   259358  ...            609 Cherry St, Dallas, TX 75001
# 1   259359  ...          225 5th St, Los Angeles, CA 90001
# 2   259360  ...       967 12th St, New York City, NY 10001
# 3   259361  ...  628 Jefferson St, New York City, NY 10001
# 4   259362  ...         534 14th St, Los Angeles, CA 90001
#
# [5 rows x 6 columns]

# %%
df11 = pd.read_csv("/content/Sales_September_2019.csv")
df11.head()
# Out:
#   Order ID  ...                       Purchase Address
# 0   248151  ...    380 North St, Los Angeles, CA 90001
# 1   248152  ...           511 8th St, Austin, TX 73301
# 2   248153  ...  151 Johnson St, Los Angeles, CA 90001
# 3   248154  ...      355 Hickory St, Seattle, WA 98101
# 4   248155  ...          125 5th St, Atlanta, GA 30301
#
# [5 rows x 6 columns]

# %%
all_months =pd.concat([df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11], ignore_index = False)
all_months.head()
# Out:
#   Order ID  ...                      Purchase Address
# 0   176558  ...          917 1st St, Dallas, TX 75001
# 1      NaN  ...                                   NaN
# 2   176559  ...     682 Chestnut St, Boston, MA 02215
# 3   176560  ...  669 Spruce St, Los Angeles, CA 90001
# 4   176560  ...  669 Spruce St, Los Angeles, CA 90001
#
# [5 rows x 6 columns]

# %%
all_months.to_csv('all_months1.csv', index = False)

# %%
import pandas as pd
all_months1 = pd.read_csv('/content/all_months1.csv')

# %%
all_months1.tail()
# Out:
#        Order ID  ...                         Purchase Address
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [5 rows x 6 columns]

# %% [markdown]
# ##CLEANING

# %%
#drop rows of NaN
Nan_df = all_months1[all_months1.isna().any(axis =1)]
Nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
#this means we have rows with Nans
all_months1 = all_months1.dropna(how= 'all')
#We use all instead of any because any will lose many of our data
all_months1.head()
# Out:
#   Order ID  ...                      Purchase Address
# 0   176558  ...          917 1st St, Dallas, TX 75001
# 2   176559  ...     682 Chestnut St, Boston, MA 02215
# 3   176560  ...  669 Spruce St, Los Angeles, CA 90001
# 4   176560  ...  669 Spruce St, Los Angeles, CA 90001
# 5   176561  ...     333 8th St, Los Angeles, CA 90001
#
# [5 rows x 6 columns]

# %%
#Find 'Or' and delete it
all_months1 = all_months1[all_months1['Order Date'].str[0:2] !='Or']
all_months1.head(1)
# Out:
#   Order ID               Product  ...      Order Date              Purchase Address
# 0   176558  USB-C Charging Cable  ...  04/19/19 08:46  917 1st St, Dallas, TX 75001
#
# [1 rows x 6 columns]

# %%
# Change data from string to int
all_months1['Quantity Ordered'] = pd.to_numeric(all_months1['Quantity Ordered'])
all_months1['Price Each'] = pd.to_numeric(all_months1['Price Each'])

# %% [markdown]
# #Augument data with additional Data

# %%
#Add month columns
all_months1['month'] =all_months1['Order Date'].str[0:2]
#we need to convert the new created column from string
all_months1['month']= all_months1['month'].astype('int32')
all_months1.head()
# Out:
#   Order ID  ... month
# 0   176558  ...     4
# 2   176559  ...     4
# 3   176560  ...     4
# 4   176560  ...     4
# 5   176561  ...     4
#
# [5 rows x 7 columns]

# %%
##Add a sales columns

all_months1['sales'] = all_months1['Quantity Ordered'] * all_months1['Price Each']
all_months1.head(5)
# Out:
#   Order ID                     Product  ...  month   sales
# 0   176558        USB-C Charging Cable  ...      4   23.90
# 2   176559  Bose SoundSport Headphones  ...      4   99.99
# 3   176560                Google Phone  ...      4  600.00
# 4   176560            Wired Headphones  ...      4   11.99
# 5   176561            Wired Headphones  ...      4   11.99
#
# [5 rows x 8 columns]

# %% [markdown]
# Task 4: Add a city column

# %%
#Add a city column
# use the .apply method - it allows us to run any function in our datframe
#we use split

#all_months1['city'] = all_months1['Purchase Address'].apply(lambda x:x.split(',')[1])
#all_months1.head()
#or we can use a function to solve this
def get_city(address):
  return address.split(',')[1]
def get_state(address):
  return address.split(',')[2].split(' ')[1]
  #then in the function, we replace the lambda to the function
all_months1['city'] = all_months1['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")  
all_months1.head()
# Out:
#   Order ID                     Product  ...   sales               city
# 0   176558        USB-C Charging Cable  ...   23.90        Dallas (TX)
# 2   176559  Bose SoundSport Headphones  ...   99.99        Boston (MA)
# 3   176560                Google Phone  ...  600.00   Los Angeles (CA)
# 4   176560            Wired Headphones  ...   11.99   Los Angeles (CA)
# 5   176561            Wired Headphones  ...   11.99   Los Angeles (CA)
#
# [5 rows x 9 columns]

# %%
all_months1.drop(columns= 'column', inplace = True)
#all_months1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-b3438a6b2310> in <module>()
# ----> 1 all_months1.drop(columns= 'column', inplace = True)
#       2 #all_months1.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
all_months1.head()

# %% [markdown]
# ###Q1. What was the best month for sales?

# %%
#We will use a group by function
result = all_months1.groupby('month').sum()

# %%
#we can plot this
import matplotlib.pyplot as plt
months = range(1,13)

plt.bar(months ,result['sales'])
plt.xticks(months)
plt.ylabel(' Sales in USD($)')
plt.xlabel('months ')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##What city had the highhest number of sales

# %%
#What city had the highhest number of sales
results = all_months1.groupby('city').sum()
results
# Out:
#                      Quantity Ordered    Price Each   month         sales
# city
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
import matplotlib.pyplot as plt

#cities = all_months1['city'].unique()
#This code shows inconistency  because it shows St Austin is largest but Fransisco is highest
#so we will use another function

cities = [city for city , df in all_months1.groupby('city')]
plt.bar(cities,results['sales'])
plt.xticks(cities, rotation = 'vertical',size =8)
plt.ylabel(' Sales in USD divided by 100,000($)')
plt.xlabel('cities ')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ###Question 3 . What time should we display advertisements to msximise likelyhood of customers buying product.

# %%
all_months1.head()
# Out:
#   Order ID                     Product  ...   sales               city
# 0   176558        USB-C Charging Cable  ...   23.90        Dallas (TX)
# 2   176559  Bose SoundSport Headphones  ...   99.99        Boston (MA)
# 3   176560                Google Phone  ...  600.00   Los Angeles (CA)
# 4   176560            Wired Headphones  ...   11.99   Los Angeles (CA)
# 5   176561            Wired Headphones  ...   11.99   Los Angeles (CA)
#
# [5 rows x 9 columns]

# %%
#WE need to change 'Order Date' string and get the two digits.
#or we can change it to date time object
all_months1['Order Date'] = pd.to_datetime(all_months1['Order Date'])

# %%
all_months1.head()
# Out:
#   Order ID                     Product  ...   sales               city
# 0   176558        USB-C Charging Cable  ...   23.90        Dallas (TX)
# 2   176559  Bose SoundSport Headphones  ...   99.99        Boston (MA)
# 3   176560                Google Phone  ...  600.00   Los Angeles (CA)
# 4   176560            Wired Headphones  ...   11.99   Los Angeles (CA)
# 5   176561            Wired Headphones  ...   11.99   Los Angeles (CA)
#
# [5 rows x 9 columns]

# %%
all_months1['Hour'] =all_months1['Order Date'].dt.hour
all_months1['minute'] =all_months1['Order Date'].dt.minute

# %%
all_months1.head()
# Out:
#   Order ID                     Product  ...  Hour  minute
# 0   176558        USB-C Charging Cable  ...     8      46
# 2   176559  Bose SoundSport Headphones  ...    22      30
# 3   176560                Google Phone  ...    14      38
# 4   176560            Wired Headphones  ...    14      38
# 5   176561            Wired Headphones  ...     9      27
#
# [5 rows x 11 columns]

# %%
#Now we can solve the problem with groupby function
hours = [hour for hour,df in all_months1.groupby('Hour')]
plt.plot(hours,all_months1.groupby(['Hour']).count())
plt.xticks(hours)
plt.grid()
plt.show()
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
all_months1.groupby(['Hour']).count()


#according the plot below, 11am and 7pm is the best time to  launch advertisements.
# Out:
#       Order ID  Product  Quantity Ordered  ...  sales   city  minute
# Hour                                       ...
# 0         3910     3910              3910  ...   3910   3910    3910
# 1         2350     2350              2350  ...   2350   2350    2350
# 2         1243     1243              1243  ...   1243   1243    1243
# 3          831      831               831  ...    831    831     831
# 4          854      854               854  ...    854    854     854
# 5         1321     1321              1321  ...   1321   1321    1321
# 6         2482     2482              2482  ...   2482   2482    2482
# 7         4011     4011              4011  ...   4011   4011    4011
# 8         6256     6256              6256  ...   6256   6256    6256
# 9         8748     8748              8748  ...   8748   8748    8748
# 10       10944    10944             10944  ...  10944  10944   10944
# 11       12411    12411             12411  ...  12411  12411   12411
# ...

# %% [markdown]
# ###Question 4. awhat product are most often sold together.

# %%
#For this we have to check for the Order ID , if there are duplicates then those items are bought o the same order.
df = all_months1[all_months1['Order ID'].duplicated(keep = False)] 
df.head(20)

df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID','Grouped']].drop_duplicates()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df.head(100)
# Out:
#      Order ID                                            Grouped
# 3      176560                      Google Phone,Wired Headphones
# 18     176574                  Google Phone,USB-C Charging Cable
# 30     176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32     176586                AAA Batteries (4-pack),Google Phone
# 119    176672      Lightning Charging Cable,USB-C Charging Cable
# ...       ...                                                ...
# 2662   179108    Lightning Charging Cable,AAA Batteries (4-pack)
# 2683   179128                    iPhone,Apple Airpods Headphones
# 2718   179162                  Google Phone,USB-C Charging Cable
# 2783   179226          34in Ultrawide Monitor,Macbook Pro Laptop
# 2829   179270                    iPhone,Lightning Charging Cable
#
# [100 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()
for row in df['Grouped']:
  row_list = row.split(',')
  count.update(Counter(combinations(row_list, 2)))

 # print(count)

  #though this is pretty messy

# to get a more readable list
for key, value in count.most_common(10):
  print(key,value)
#to know the common 3 , just change in count.update the number
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %%
df.head(100)
# Out:
#      Order ID  ...                                           Grouped
# 3      176560  ...                      Google Phone,Wired Headphones
# 4      176560  ...                      Google Phone,Wired Headphones
# 18     176574  ...                  Google Phone,USB-C Charging Cable
# 19     176574  ...                  Google Phone,USB-C Charging Cable
# 30     176585  ...  Bose SoundSport Headphones,Bose SoundSport Hea...
# ...       ...  ...                                                ...
# 1077   177582  ...        Bose SoundSport Headphones,Wired Headphones
# 1078   177582  ...        Bose SoundSport Headphones,Wired Headphones
# 1088   177592  ...                    iPhone,Lightning Charging Cable
# 1089   177592  ...                    iPhone,Lightning Charging Cable
# 1135   177638  ...              Apple Airpods Headphones,Google Phone
#
# [100 rows x 12 columns]

# %% [markdown]
# ### Question 4. What product sold the most? Why do you think it sold the most?

# %%
product_group = all_months1.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']


products = [product for product, df in product_group]
plt.bar(products , quantity_ordered)
plt.xlabel('product')
plt.ylabel('Quantity Ordered')
plt.xticks(products, rotation = 'vertical',size = 9)
plt.show()

# %%
#Why are some higher than others
#look for some correlation

prices = all_months1.groupby('Product').mean()['Price Each']
#adding second y axis on matplotlib chart

fig,ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(products , quantity_ordered, color ='g')
ax2.plot(products,prices, 'b-')


ax1.set_xlabel('Product name')
ax1.set_ylabel('Quantity Ordered', color = 'g')
ax2.set_ylabel('price ($)', color = 'b')
ax1.set_xticklabels(products, rotation = 'vertical', size = 8)
plt.show()
